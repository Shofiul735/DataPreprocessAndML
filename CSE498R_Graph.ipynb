# %%
import pandas as pd

# %%
df = pd.read_csv('cse498R.csv')

# %%
df.head()
# Out:
#              Timestamp Your gender Category that includes your age  \
# 0  01/01/2022 14:41:44      Female                           22-25
# 1  01/01/2022 14:43:41        Male                           22-25
# 2  01/01/2022 14:56:43        Male                           22-25
# 3  01/01/2022 15:12:24      Female                           17-21
# 4  01/01/2022 15:15:39      Female                           22-25
#
#   Your education state Currently you are a/an  Your marital status   \
# 0        Undergraduate                 Student               Single
# 1        Undergraduate                 Student               Single
# 2        Undergraduate                 Student               Single
# 3        Undergraduate                 Student               Single
# 4        Undergraduate                 Student               Single
#
#   Your family structure Are you happy with the family you belong?  \
# 0       Neuclear family                                        No
# ...

# %% [markdown]
# # Gender

# %%
df['Your gender'].value_counts().plot(kind='bar',title="Gender")
# Out:
# <AxesSubplot:title={'center':'Gender'}>

# %%
df['Your gender'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Your gender'>

# %%
df['Your gender'].value_counts().plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Age

# %%
df['Category that includes your age'].value_counts().plot(kind='barh',title='Age')
# Out:
# <AxesSubplot:title={'center':'Age'}>

# %%
df['Category that includes your age'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Category that includes your age'>

# %%
df['Category that includes your age'].value_counts().plot(kind='line',title='Age')
# Out:
# <AxesSubplot:title={'center':'Age'}>

# %% [markdown]
# # family structure

# %%
df['Your family structure'].value_counts().plot(kind='barh',title='Current family structure')
# Out:
# <AxesSubplot:title={'center':'Current family structure'}>

# %%
df['Your family structure'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Your family structure'>

# %%
df['Your family structure'].value_counts().plot(kind='line',title='Current family structure')
# Out:
# <AxesSubplot:title={'center':'Current family structure'}>

# %% [markdown]
# # Preferable family structure

# %%
df['What kind of family will you prefer after your marriage?'].value_counts().plot(kind='barh',title='Preferable family structure')
# Out:
# <AxesSubplot:title={'center':'Preferable family structure'}>

# %%
df['What kind of family will you prefer after your marriage?'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='What kind of family will you prefer after your marriage?'>

# %%
df['What kind of family will you prefer after your marriage?'].value_counts().plot(kind='line',title='Preferable family structure')
# Out:
# <AxesSubplot:title={'center':'Preferable family structure'}>

# %% [markdown]
# # 'How often you agree with your parents in any matter?'

# %%
df['How often you agree with your parents in any matter?'].value_counts().plot(kind='barh',title='How often you agree with your parents in any matter?')
# Out:
# <AxesSubplot:title={'center':'How often you agree with your parents in any matter?'}>

# %%
df['How often you agree with your parents in any matter?'].value_counts().plot(kind='pie',ylabel='',title='How often you agree with your parents in any matter?')
# Out:
# <AxesSubplot:title={'center':'How often you agree with your parents in any matter?'}>

# %%
df['How often you agree with your parents in any matter?'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 'What's your financial aim? '

# %%
df["What's your financial aim? "].value_counts().plot(kind='barh',title='Financial aim?')
# Out:
# <AxesSubplot:title={'center':'Financial aim?'}>

# %%
df["What's your financial aim? "].value_counts().plot(kind='pie',ylabel='',title="What's your financial aim?")
# Out:
# <AxesSubplot:title={'center':"What's your financial aim?"}>

# %%
df["What's your financial aim? "].value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['Timestamp', 'Your gender', 'Category that includes your age',
#        'Your education state', 'Currently you are a/an ',
#        'Your marital status ', 'Your family structure',
#        'Are you happy with the family you belong?',
#        'What's describe your parents best? (you can choose multiple option here)',
#        'How often you agree with your parents in any matter?',
#        'What's your opinion about your relatives?',
#        'Your preferable age for marriage', 'What kind of marriage you want?',
#        ' Which culture do you think is better?',
#        'Importance of marriage to you?',
#        'What is the first trait do you look for in your partner?',
#        'What's your financial aim? ', 'Your partner should be',
#        'Preferable financial state of your partner',
#        'What should be your role for your parents-in-law?',
#        'What kind of family will you prefer after your marriage?',
#        'How many children you want?',
# ...

# %%
df['Preferable financial state of your partner'].value_counts().plot(kind="barh",title="'Preferable financial state of your partner'")
# Out:
# <AxesSubplot:title={'center':"'Preferable financial state of your partner'"}>

# %%
df['Preferable financial state of your partner'].value_counts().plot(kind="pie",ylabel='',title='Preferable financial state of your partner')
# Out:
# <AxesSubplot:title={'center':'Preferable financial state of your partner'}>

# %% [markdown]
# # What should be your role for your parents-in-law?

# %%
df['What should be your role for your parents-in-law?'].value_counts().plot(kind='barh',title='What should be your role for your parents-in-law?')
# Out:
# <AxesSubplot:title={'center':'What should be your role for your parents-in-law?'}>

# %%
df['What should be your role for your parents-in-law?'].value_counts().plot(kind='line',title='What should be your role for your parents-in-law?')
# Out:
# <AxesSubplot:title={'center':'What should be your role for your parents-in-law?'}>

# %% [markdown]
# # 'In future if you ever think of getting divorce, what will stop you?'

# %%
df['In future if you ever think of getting divorce, what will stop you?'].value_counts().plot(kind='barh',title='What will stop to getting divorce')
# Out:
# <AxesSubplot:title={'center':'What will stop to getting divorce'}>

# %%
df['In future if you ever think of getting divorce, what will stop you?'].value_counts().plot(kind='line',title='What will stop to getting divorce')
# Out:
# <AxesSubplot:title={'center':'What will stop to getting divorce'}>

# %%
df['In future if you ever think of getting divorce, what will stop you?'].value_counts().plot(kind='pie',ylabel='',title='What will stop to getting divorce')
# Out:
# <AxesSubplot:title={'center':'What will stop to getting divorce'}>

# %% [markdown]
# # 'Do you think we should normalize divorce in our society?'

# %%
df['Do you think we should normalize divorce in our society?'].value_counts().plot(kind='barh',title='Do you think we should normalize divorce in our society?')
# Out:
# <AxesSubplot:title={'center':'Do you think we should normalize divorce in our society?'}>

# %%
df['Do you think we should normalize divorce in our society?'].value_counts().plot(kind='pie',ylabel='',title='Do you think we should normalize divorce in our society?')
# Out:
# <AxesSubplot:title={'center':'Do you think we should normalize divorce in our society?'}>

# %%
df['Do you think we should normalize divorce in our society?'].value_counts().plot(kind='box',title='Do you think we should normalize divorce in our society?')
# Out:
# <AxesSubplot:title={'center':'Do you think we should normalize divorce in our society?'}>

# %% [markdown]
# # 'How many children you want?'

# %%
df['How many children you want?'].value_counts().plot(kind='barh',title='How many children you want?')
# Out:
# <AxesSubplot:title={'center':'How many children you want?'}>

# %%
df['How many children you want?'].value_counts().plot(kind='pie',title='How many children you want?')
# Out:
# <AxesSubplot:title={'center':'How many children you want?'}, ylabel='How many children you want?'>

# %%
df['How many children you want?'].value_counts().plot(kind='line',title='How many children you want?')
# Out:
# <AxesSubplot:title={'center':'How many children you want?'}>

# %%
df.columns
# Out:
# Index(['Timestamp', 'Your gender', 'Category that includes your age',
#        'Your education state', 'Currently you are a/an ',
#        'Your marital status ', 'Your family structure',
#        'Are you happy with the family you belong?',
#        'What's describe your parents best? (you can choose multiple option here)',
#        'How often you agree with your parents in any matter?',
#        'What's your opinion about your relatives?',
#        'Your preferable age for marriage', 'What kind of marriage you want?',
#        ' Which culture do you think is better?',
#        'Importance of marriage to you?',
#        'What is the first trait do you look for in your partner?',
#        'What's your financial aim? ', 'Your partner should be',
#        'Preferable financial state of your partner',
#        'What should be your role for your parents-in-law?',
#        'What kind of family will you prefer after your marriage?',
#        'How many children you want?',
# ...

# %%
df['Category that includes your age'].value_counts()
# Out:
# 22-25    132
# 17-21     65
# 26-30     29
# 30+        9
# Name: Category that includes your age, dtype: int64

# %%
df['Category that includes your age'].replace('22-25',23,inplace=True)
df['Category that includes your age'].replace('17-21',19,inplace=True)
df['Category that includes your age'].replace('26-30',27,inplace=True)
df['Category that includes your age'].replace('30+',40,inplace=True)

# %%
df['Category that includes your age'].describe()
# Out:
# count    235.000000
# mean      23.038298
# std        4.188229
# min       19.000000
# 25%       19.000000
# 50%       23.000000
# 75%       23.000000
# max       40.000000
# Name: Category that includes your age, dtype: float64

# %% [markdown]
# # Future Neuclear Family

# %%
mask = df['Your family structure']=='Joint family'

# %%
df_joint = df[mask]
df_joint['Your family structure'].count() #total join family
# Out:
# 58

# %%
mask = df_joint['What kind of family will you prefer after your marriage?'] == 'Neuclear family'

# %%
df_joint[mask].count()
# Out:
# Timestamp                                                                                             24
# Your gender                                                                                           24
# Category that includes your age                                                                       24
# Your education state                                                                                  24
# Currently you are a/an                                                                                24
# Your marital status                                                                                   24
# Your family structure                                                                                 24
# Are you happy with the family you belong?                                                             24
# What's describe your parents best? (you can choose multiple option here)                              24
# ...

# %%
print((24/58*100),'%')
# Out:
# 41.37931034482759 %

# %%
'That means half of the joint family going to be neuclear family'
# Out:
# 'That means half of the joint family going to be neuclear family'

# %%
d = {'Belong in Joint Family': 58, 'Prefer Neuclear family in future': 24}
s = pd.Series(data=d,index=['Belong in Joint Family','Prefer Neuclear family in future'])

# %%
s.sort_values().plot(kind='barh',title='Joint Family vs Future neuclear Family')
# Out:
# <AxesSubplot:title={'center':'Joint Family vs Future neuclear Family'}>

# %%
s.plot(kind='pie',ylabel='',title='Joint Family vs Future neuclear Family')
# Out:
# <AxesSubplot:title={'center':'Joint Family vs Future neuclear Family'}>

# %%
mask = df['Your family structure']=='Joint family'
mask1 = df['Are you happy with the family you belong?']=='Yes'

# %%
mask = mask&mask1

# %%
joint_and_happy = df[mask]
joint_and_happy.count()
# Out:
# Timestamp                                                                                             40
# Your gender                                                                                           40
# Category that includes your age                                                                       40
# Your education state                                                                                  40
# Currently you are a/an                                                                                40
# Your marital status                                                                                   40
# Your family structure                                                                                 40
# Are you happy with the family you belong?                                                             40
# What's describe your parents best? (you can choose multiple option here)                              40
# ...

# %%
mask2 = joint_and_happy['What kind of family will you prefer after your marriage?'] == 'Neuclear family'

# %%
joint_and_happy_neuclear = joint_and_happy[mask2]

# %%
joint_and_happy_neuclear.count()
# Out:
# Timestamp                                                                                             10
# Your gender                                                                                           10
# Category that includes your age                                                                       10
# Your education state                                                                                  10
# Currently you are a/an                                                                                10
# Your marital status                                                                                   10
# Your family structure                                                                                 10
# Are you happy with the family you belong?                                                             10
# What's describe your parents best? (you can choose multiple option here)                              10
# ...

# %%
d = {'Joint family and Happy':40,'But want neuclear family in future':10}
joint_but_neuclear = pd.Series(data=d,index=['Joint family and Happy','But want neuclear family in future'])

# %%
joint_but_neuclear.sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
joint_but_neuclear.plot(kind='pie',ylabel='')
# Out:
# <AxesSubplot:>

# %%
print(10/58*100,'%')
# Out:
# 17.24137931034483 %
